# %%
# %python
df = spark.sql("SELECT * FROM samples.nyctaxi.trips LIMIT 100")
display(df)

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.workspace")
df.write.saveAsTable("workspace.workspace.nyctaxi_trips_sample")

# %%
display(df)
# Out:
# Databricks visualization. Run in Databricks to view.
